# %%
import requests
BASE_URL = 'https://tele-tv-be.onrender.com'
# Esegui la richiesta GET
endpoint = f"{BASE_URL}/chats"
response = requests.get(endpoint)

# Controlla lo stato della risposta
if response.status_code == 200:
    print("Richiesta riuscita!")
    print(response.json())  # Se la risposta è in formato JSON
else:
    print(f"Errore {response.status_code}: {response.text}")

response.json()

# %%
#get test app chat
test_app_id = '-4770197712'
endpoint = f"{BASE_URL}/messages/{test_app_id}"
response = requests.get(endpoint)

# Controlla lo stato della risposta
if response.status_code == 200:
    print("Richiesta riuscita!")
    print(response.json())  # Se la risposta è in formato JSON
else:
    print(f"Errore {response.status_code}: {response.text}")

response.json()
# Out:
# Richiesta riuscita!
# ...

# %%
message_id = 664396
response = requests.get(f"{BASE_URL}/download/{message_id}")

if response.status_code == 200:
    with open("video.mp4", "wb") as f:
        f.write(response.content)
    print("✅ Video scaricato come video.mp4")
else:W
    print(f"❌ Errore {response.status_code}: {response.text}")
# Out:
# ✅ Video scaricato come video.mp4
